# %% [markdown]
# ### Import the necessary modules

# %%
from bs4 import BeautifulSoup
from io import BytesIO
import pandas as pd
import requests
import PyPDF2
import re

# %% [markdown]
# ### Functions

# %%
def read_page(url, page):
    response = requests.get('https://covid19.saglik.gov.tr' + link)
    
    pdfFileObj = BytesIO(response.content)
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    pageObj = pdfReader.getPage(page)

    return pageObj.extractText()

# %%
def parse_data(data):
    parsed = data
    parsed = parsed[parsed.index("Istanbul"):]
    parsed = parsed[:parsed.index("Turkey")]
    
    return re.findall(r"([a-zA-Z ]+)[\n -]*([0-9,.]+)[\n -]*", parsed)

# %%
def get_row(parsed, dt, key, value):
    df_data = {"Date": pd.to_datetime(dt, format='%d%m%Y', errors='ignore')}
    for pair in parsed:
        df_data[pair[key].replace('\n', '')] = [pair[value]]
    return pd.DataFrame(df_data)

# %% [markdown]
# ### Program

# %%
saglik_url = 'https://covid19.saglik.gov.tr/TR-68444/gunluk-rapor--daily-report.html'

response = requests.get(saglik_url)
content = response.content

# %%
soup = BeautifulSoup(content, 'html.parser')

links = [link.get('href') for link in soup.select('tbody a')]

eng = re.compile('.*eng.html')

links = [link for link in links if eng.match(link)]

# %%
df_patient = pd.DataFrame()
df_hospitalization = pd.DataFrame()
df_hospital_discharge = pd.DataFrame()

for link in links:
    date = re.search("-(\d*)-eng.html", link).group(1)
    
    if date == '14082020': # The link is broken
        continue
    
    data = read_page(link, page=4)
    parsed = data[data.index("Istanbul"):]
    parsed = parsed[:parsed.index("Turkey")]

    parsed =  re.findall(r"([A-Z][a-zA-Z \n]*[a-z])[\n -]+([0-9.]+)[\n -]+.*[\n -]+([0-9.]+)", parsed)
    df_hospitalization = pd.concat([df_hospitalization, get_row(parsed, date, key=0, value=1)])
    df_hospital_discharge = pd.concat([df_hospital_discharge, get_row(parsed, date, key=0, value=2)])
    
    data = read_page(link, page=2)
    parsed = data[data.index("Istanbul"):]
    parsed = parsed[:parsed.index("Turkey")]
    parsed =  re.findall(r"([A-Z][a-zA-Z \n]*[a-z])[\n -]+([0-9.]+)", parsed)
    df_patient = pd.concat([df_patient, get_row(parsed, date, key=0, value=1)])
    
    print('record date:', date)
# Out:
# record date: 23112020
# record date: 22112020
# record date: 21112020
# record date: 20112020
# record date: 19112020
# record date: 18112020
# record date: 17112020
# record date: 16112020
# record date: 15112020
# record date: 14112020
# record date: 13112020
# record date: 12112020
# record date: 11112020
# record date: 10112020
# record date: 09112020
# record date: 08112020
# record date: 07112020
# record date: 06112020
# record date: 05112020
# record date: 04112020
# record date: 03112020
# record date: 02112020
# record date: 01112020
# record date: 31102020
# record date: 30102020
# record date: 29102020
# record date: 28102020
# record date: 27102020
# record date: 26102020
# record date: 25102020
# record date: 24102020
# record date: 23102020
# record date: 22102020
# record date: 21102020
# record date: 20102020
# record date: 19102020
# record date: 18102020
# record date: 17102020
# record date: 16102020
# record date: 15102020
# record date: 14102020
# record date: 13102020
# record date: 12102020
# record date: 11102020
# record date: 10102020
# record date: 09102020
# record date: 08102020
# record date: 07102020
# record date: 06102020
# record date: 05102020
# record date: 04102020
# record date: 03102020
# record date: 02102020
# record date: 01102020
# record date: 30092020
# record date: 29092020
# record date: 28092020
# record date: 27092020
# record date: 26092020
# record date: 25092020
# record date: 24092020
# record date: 23092020
# record date: 22092020
# record date: 21092020
# record date: 20092020
# record date: 19092020
# record date: 18092020
# record date: 17092020
# record date: 16092020
# record date: 15092020
# record date: 14092020
# record date: 13092020
# record date: 12092020
# record date: 11092020
# record date: 10092020
# record date: 09092020
# record date: 08092020
# record date: 07092020
# record date: 06092020
# record date: 05092020
# record date: 04092020
# record date: 03092020
# record date: 02092020
# record date: 01092020
# record date: 31082020
# record date: 30082020
# record date: 29082020
# record date: 28082020
# record date: 27082020
# record date: 26082020
# record date: 25082020
# record date: 24082020
# record date: 23082020
# record date: 22082020
# record date: 21082020
# record date: 20082020
# record date: 19082020
# record date: 18082020
# record date: 17082020
# record date: 16082020
# record date: 15082020
# record date: 13082020
# record date: 12082020
# record date: 11082020
# record date: 10082020
# record date: 09082020
# record date: 08082020
# record date: 07082020
# record date: 06082020
# record date: 05082020
# record date: 04082020
# record date: 03082020
# record date: 02082020
# record date: 01082020
# record date: 31072020
# record date: 30072020
# record date: 29072020
# record date: 28072020
# record date: 27072020
# record date: 26072020
# record date: 25072020
# record date: 24072020
# record date: 23072020
# record date: 22072020
# record date: 21072020
# record date: 20072020
# record date: 19072020
# record date: 18072020
# record date: 17072020
# record date: 16072020
# record date: 15072020
# record date: 14072020
# record date: 13072020
# record date: 12072020
# record date: 11072020
# record date: 10072020
# record date: 09072020
# record date: 08072020
# record date: 07072020
# record date: 06072020
# record date: 05072020
# record date: 04072020
# record date: 03072020
# record date: 02072020
# record date: 01072020
# record date: 30062020
# record date: 29062020

# %%
df_patient.head()
# Out:
#         Date Istanbul Western Marmara Aegean Eastern Marmara Western Anatolia  \
# 0 2020-11-23    1.557             234    893             899              533
# 0 2020-11-22    1.361             262    902             733              433
# 0 2020-11-21    1.404             234    810             792              367
# 0 2020-11-20    1.289             236    695             697              368
# 0 2020-11-19    1.161             171    603             696              347
#
#   Mediterranean Central Anatolia Western Blacksea Eastern Blacksea  \
# 0           728              294              551              226
# 0           711              232              504              179
# 0           564              199              368              167
# 0           515              213              350              156
# 0           430              175              320              134
#
#   Northeastern Anatolia Mideastern Anatolia Southeastern Anatolia
# 0                   137                 193                   468
# 0                   110                 187                   402
# 0                   101                 137                   389
# 0                    99                 135                   350
# 0                    86                 129                   289

# %%
df_hospitalization.head()
# Out:
#         Date Istanbul Western Marmara Aegean Eastern Marmara Western Anatolia  \
# 0 2020-11-23      159              32     93             124               81
# 0 2020-11-22      149              36    101             113               61
# 0 2020-11-21      165              31     95             119               72
# 0 2020-11-20      159              34    103             131               68
# 0 2020-11-19      165              34    106             123               76
#
#   Mediterranean Central Anatolia Western Blacksea Eastern Blacksea  \
# 0            92               39               64               24
# 0            65               42               62               24
# 0            81               42               62               21
# 0            91               45               55               21
# 0            83               38               61               22
#
#   Northeastern Anatolia Mideastern Anatolia Southeastern Anatolia
# 0                    21                  22                    60
# 0                    19                  24                    58
# 0                    26                  25                    58
# 0                    22                  21                    57
# 0                    21                  22                    62

# %%
df_hospital_discharge.head()
# Out:
#         Date Istanbul Western Marmara Aegean Eastern Marmara Western Anatolia  \
# 0 2020-11-23      137              24     66              99               52
# 0 2020-11-22      117              21     59              97               49
# 0 2020-11-21      133              25     68             109               57
# 0 2020-11-20      133              25     74             106               52
# 0 2020-11-19      131              23     71              94               62
#
#   Mediterranean Central Anatolia Western Blacksea Eastern Blacksea  \
# 0            59               27               37               14
# 0            52               29               42               13
# 0            61               34               43               16
# 0            62               29               41               13
# 0            53               34               50               15
#
#   Northeastern Anatolia Mideastern Anatolia Southeastern Anatolia
# 0                    16                  23                    59
# 0                    22                  24                    50
# 0                    21                  24                    53
# 0                    17                  26                    60
# 0                    18                  23                    54
